# %%
df = spark.read.table('databricksmayank.silver.sales_enr')

# %%
display(df)

# %%
# %sql
select * from databricksmayank.silver.sales_enr

# %%
# %sql
drop table databricksmayank.bronze.source;

# %%
# %sql
create table databricksmayank.bronze.source
(
  product_id int,
  product string,
  processDate timestamp
);

# %%
# %sql
Insert into databricksmayank.bronze.source
values
(1,'bread',current_timestamp()),
(2,'honey',current_timestamp()),
(3,'honey',current_timestamp())

# %%
# %sql
select * from databricksmayank.dlt_schema.scd1_table

# %%
# %sql
select * from databricksmayank.dlt_schema.scd2_table

# %%
# %sql
Insert into databricksmayank.bronze.source
values
(1,'bread',current_timestamp()),
(2,'honey',current_timestamp()),
(3,'multigrain',current_timestamp()),
(4,'mint',current_timestamp())

# %%
# %sql
select * from databricksmayank.dlt_schema.scd1_table

# %%
# %sql
select * from databricksmayank.dlt_schema.scd2_table

# %%
# %sql
select * from databricksmayank.dlt_schema.scd3_table

# %%
# %sql
Insert into databricksmayank.bronze.source
values
(1,'bread',current_timestamp()),
(2,'honey',current_timestamp()),
(3,'multigrain',current_timestamp()),
(4,'mint',current_timestamp()),
(5,'WholeWheatBread',current_timestamp())

# %%
# %sql
select * from databricksmayank.dlt_schema.scd1_table

# %%
# %sql
select * from databricksmayank.dlt_schema.scd2_table

# %%
# %sql
select * from databricksmayank.dlt_schema.scd3_table
