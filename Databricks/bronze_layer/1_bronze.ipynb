# %%
print("hello")

# %%
# %sql
select "mayank"

# %% [markdown]
# # Volumes

# %%
# %sql
create  volume databricksmayank.bronze.bronze_volume

# %%
# %sql
SELECT * FROM read_files('/Volumes/databricksmayank/bronze/bronze_volume/sales', format => 'csv', header => true)

# %%
# %sql
select * from csv.`/Volumes/databricksmayank/bronze/bronze_volume/sales/fact_sales.csv`

# %% [markdown]
# # DBUTILS

# %%
dbutils.help()

# %%
dbutils.fs.help()

# %%
dbutils.fs.ls("/Volumes/databricksmayank/bronze/bronze_volume/sales/")

# %%
dbutils.fs.mkdirs("/Volumes/databricksmayank/bronze/bronze_volume/customers/")

# %%
dbutils.fs.cp("/Volumes/databricksmayank/bronze/bronze_volume/sales/","/Volumes/databricksmayank/bronze/bronze_volume/customers/",True)

# %%
for i in file_names:
  dbutils.fs.cp("/Volumes/databricksmayank/bronze/bronze_volume/sales/"+i,"/Volumes/databricksmayank/bronze/bronze_volume/customers/",True)

# %%
dbutils.fs.rm("/Volumes/databricksmayank/bronze/bronze_volume/customers/fact_sales.csv")

# %%
dbutils.fs.rm("/Volumes/databricksmayank/bronze/bronze_volume/customers/", recurse=True)

# %%
for i in file_names:
  dbutils.fs.rm(f"/Volumes/databricksmayank/bronze/bronze_volume/customers/{i}")

# %%
dbutils.fs.put("/Volumes/databricksmayank/bronze/bronze_volume/customers/test1.txt", "Hello Mayank Chugh")

# %%
dbutils.fs.put("/Volumes/databricksmayank/bronze/bronze_volume/customers/test1.txt", "Hello Mayank Chugh",True)

# %%
dbutils.fs.put("/Volumes/databricksmayank/bronze/bronze_volume/customers/test.py", "print('Hello Mayank Chugh')")

# %%
all_items = dbutils.fs.ls("/Volumes/databricksmayank/bronze/bronze_volume/customers/")
all_items

# %%
file_names = [i.name for i in all_items]
file_names

# %%
dbutils.widgets.text("par1","")

# %%
par1_value = dbutils.widgets.get("par1")
par1_value

# %%
print(par1_value)
