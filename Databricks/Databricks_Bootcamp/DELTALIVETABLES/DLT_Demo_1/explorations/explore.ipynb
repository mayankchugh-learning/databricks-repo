# %%
df = spark.read.table("databricksansh.silver.sales_enr")

# %%
display(df)

# %%
# %sql
CREATE TABLE databricksansh.bronze.source
(
  product_id INT,
  product_name STRING,
  processDate TIMESTAMP
)

# %%
# %sql
INSERT INTO databricksansh.bronze.source 
VALUES
(1,'honey',current_timestamp()),
(2,'milk',current_timestamp()),
(3,'wholeWheatBread',current_timestamp()),
(4,'mint',current_timestamp())

# %%
# %sql
SELECT * FROM databricksansh.dlt_schema.scd1_table

# %%
# %sql
SELECT * FROM databricksansh.dlt_schema.scd3_table
