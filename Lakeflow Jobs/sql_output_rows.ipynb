# %%
dbutils.widgets.text("sql_output","")

# %%
sql_output_text = dbutils.widgets.get("sql_output")
sql_output_text

# %%
from pyspark.sql.functions import *

# %%
sql_output_list = eval(sql_output_text) if sql_output_text else []
sql_output_list
