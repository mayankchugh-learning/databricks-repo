# %%
dbutils.widgets.text('folder_name', '')
dbutils.widgets.text('parent_folder_name', '')

# %%
folder_name = dbutils.widgets.get('folder_name')
parent_folder_name = dbutils.widgets.get('parent_folder_name')

# %%
df = spark.read.format('csv')\
    .option('header','true')\
        .option('inferSchema','true').\
            load(f'/Volumes/databricksmayank/bronze/bronze_volume/{folder_name}/')

# %%
# df.write.format('parquet').save(f'/Volumes/databricksmayank/bronze/jobvolume/{parent_folder_name}/{folder_name}/')

# %%
df.write.format('parquet').mode('overwrite').save(f'/Volumes/databricksmayank/bronze/jobvolume/{parent_folder_name}/{folder_name}/')
