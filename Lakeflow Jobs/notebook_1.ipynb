# %% [markdown]
# create volume databricksmayank.bronze.jobvolume

# %%
df = spark.read.format("csv")\
    .option("header", "true")\
    .option("inferSchema", "true")\
    .load("/Volumes/databricksmayank/bronze/bronze_volume/stores/")

# %%
df.write.format("delta")\
    .mode("overwrite")\
        .save("/Volumes/databricksmayank/bronze/jobvolume/raw/stores")
