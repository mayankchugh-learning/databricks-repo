# %%
dbutils.widgets.text("para1", "")

# %%
para_value = dbutils.widgets.get("para1")
print(para_value)

# %% [markdown]
# ##### GET VALUE

# %%
try:
    var2 = dbutils.job.taskValues.get("lookup", "lookup_output")
except AttributeError:
    # dbutils.job is only available in job context, not interactive notebooks
    var2 = None
var2

# %%
var3 = dbutils.jobs.taskValues.get("lookup", "lookup_output", debugValue='')
var3
