-- %%
DROP TABLE databricksmayank.bronze.lookup_table;

CREATE TABLE databricksmayank.bronze.lookup_table
(
  parent_folder_name STRING,
  folder_name STRING
);

INSERT INTO databricksmayank.bronze.lookup_table
VALUES
('raw', 'customers'),
('raw', 'products'),
('raw', 'stores'),
('raw', 'sales');

select * from databricksmayank.bronze.lookup_table;
