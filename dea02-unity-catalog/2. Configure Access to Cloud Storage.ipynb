# %% [markdown]
# ### Configure Access to Cloud Storag via Unity Catalog

# %%
# %fs ls 'abfss://deaextdlmc.dfs.core.windows.net/'

# %% [markdown]
# ##### Create External Location

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS dea_ext_dl_demo
  URL 'abfss://deaextdlmc.dfs.core.windows.net/'
  WITH (storage credential dea_brick_ws)
  COMMENT 'External location for demo'
